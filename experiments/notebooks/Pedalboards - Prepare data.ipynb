# %%
# %matplotlib inline
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('../data/pedalboard-plugin-full-bag-of-words.csv', sep=",", index_col=['index', 'id'])

# %%
data[[f'{i}.5' for i in range(117)]].sum().sort_values(ascending=False).plot.pie()

# %%
x_train, x_test = train_test_split(data_copy, test_size=.2, random_state=42)

# %%
i = int(len(x_train.columns) / 6)

columns_train = data.columns[:i*5]
columns_test = data.columns[i*5:]

x_train, y_train = x_train[columns_train], x_train[columns_test]
x_test, y_test = x_test[columns_train], x_test[columns_test]

# %%
x_train.to_csv('../data/pedalboard-plugin-x_train.csv')
y_train.to_csv('../data/pedalboard-plugin-y_train.csv')

x_test.to_csv('../data/pedalboard-plugin-x_test.csv')
y_test.to_csv('../data/pedalboard-plugin-y_test.csv')
